# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style("whitegrid")

# %%
5 + 5
# Out:
# 10

# %%
ga_all = pd.read_csv('GA-all.csv')
ga_all.head()
# Out:
#     id pdb_id  bp_id idstr1  idstr2 symbol   bpname  saenger   lw  dssr  \
# 0   51   1CSL      5  A.G47   B.A73    G-A    Imino  08-VIII  cWW  cW-W
# 1   66   1DFU      8  M.G98   N.A78    G-A  Sheared    11-XI  tSH  tm-M
# 2   69   1DFU     11  N.G75  M.A101    G-A       --      n/a  c.W  c.-W
# 3   72   1DFU     14  N.G72  M.A104    G-A  Sheared    11-XI  tSH  tm-M
# 4  107   1E7K      4  D.G32   D.A44    G-A  Sheared    11-XI  tSH  tm-M
#
#                          ...                         shear  stretch stagger  \
# 0                        ...                         -0.19     1.50   -0.21
# 1                        ...                          6.80    -4.19    0.02
# 2                        ...                         -0.45     2.85   -0.82
# 3                        ...                          6.85    -4.17   -0.25
# 4                        ...                          6.40    -4.35    0.10
#
#   buckle  propeller  opening  \
# 0 -16.39       0.01   -20.73
# ...

# %%
columns = ['id','bp_id','idstr1','idstr2','symbol','bpname','saenger','lw','summary1','summary2']

# %%
ga_all.drop(columns,axis = 1, inplace = True)

# %%
ga_all.head()
# Out:
#   pdb_id  dssr wc_geo    chi1 syn_anti1     pucker1  lambda1    chi2  \
# 0   1CSL  cW-W      y -167.16      anti   ~C3'-endo    44.47  172.19
# 1   1DFU  tm-M      n -172.30      anti   ~C3'-endo    98.55 -168.04
# 2   1DFU  c.-W      n -158.75      anti   ~C3'-endo    24.72 -165.01
# 3   1DFU  tm-M      n -155.60      anti   ~C3'-endo    98.28 -168.76
# 4   1E7K  tm-M      n -107.93      anti  ~C2'-endo    100.59 -135.15
#
#   syn_anti2     pucker2                        ...                          \
# 0      anti   ~C3'-endo                        ...
# 1      anti   ~C3'-endo                        ...
# 2      anti   ~C3'-endo                        ...
# 3      anti   ~C3'-endo                        ...
# 4      anti  ~C2'-endo                         ...
#
#     torCN    dWC  shear  stretch  stagger  buckle  propeller  opening  hb_num  \
# 0    7.26 -23.30  -0.19     1.50    -0.21  -16.39       0.01   -20.73       2
# ...

# %%
cols = ['pdb_id','wc_geo','chi1','syn_anti1','pucker1','lambda1','pucker2','torCN','dWC']
ga_all.drop(cols,axis = 1, inplace = True)

# %%
col = ['chi2','syn_anti2','lambda2','dC1C1','dN1N9','dC6C8','propeller','buckle','stagger']
ga_all.drop(col,axis = 1, inplace = True)

# %%
ga_all.head()
# Out:
#    dssr  shear  stretch  opening  hb_num  \
# 0  cW-W  -0.19     1.50   -20.73       2
# 1  tm-M   6.80    -4.19    -1.74       3
# 2  c.-W  -0.45     2.85   -60.83       1
# 3  tm-M   6.85    -4.17    -3.77       3
# 4  tm-M   6.40    -4.35     1.87       3
#
#                                               hb_str
# 0    O6(carbonyl)-N6(amino)[2.78],N1(imino)-N1[2.91]
# 1  O2'(hydroxyl)-N6(amino)[2.85],N2(amino)-N7[2.9...
# 2                       O6(carbonyl)-N6(amino)[2.91]
# 3  O2'(hydroxyl)-N6(amino)[2.95],N2(amino)-N7[2.9...
# 4  O4'-N6(amino)[3.29],N2(amino)-N7[2.86],N3-N6(a...

# %%
ga_all['dssr'] = ga_all['dssr'].apply(lambda x: x[1:])

# %%
ga_all.head()
# Out:
#   dssr  shear  stretch  opening  hb_num  \
# 0  W-W  -0.19     1.50   -20.73       2
# 1  m-M   6.80    -4.19    -1.74       3
# 2  .-W  -0.45     2.85   -60.83       1
# 3  m-M   6.85    -4.17    -3.77       3
# 4  m-M   6.40    -4.35     1.87       3
#
#                                               hb_str
# 0    O6(carbonyl)-N6(amino)[2.78],N1(imino)-N1[2.91]
# 1  O2'(hydroxyl)-N6(amino)[2.85],N2(amino)-N7[2.9...
# 2                       O6(carbonyl)-N6(amino)[2.91]
# 3  O2'(hydroxyl)-N6(amino)[2.95],N2(amino)-N7[2.9...
# 4  O4'-N6(amino)[3.29],N2(amino)-N7[2.86],N3-N6(a...

# %%
ga_all_minus = ga_all[ga_all['dssr'].str.contains('-')]

# %%
ga_all_minus.head()
# Out:
#   dssr  shear  stretch  opening  hb_num  \
# 0  W-W  -0.19     1.50   -20.73       2
# 1  m-M   6.80    -4.19    -1.74       3
# 2  .-W  -0.45     2.85   -60.83       1
# 3  m-M   6.85    -4.17    -3.77       3
# 4  m-M   6.40    -4.35     1.87       3
#
#                                               hb_str
# 0    O6(carbonyl)-N6(amino)[2.78],N1(imino)-N1[2.91]
# 1  O2'(hydroxyl)-N6(amino)[2.85],N2(amino)-N7[2.9...
# 2                       O6(carbonyl)-N6(amino)[2.91]
# 3  O2'(hydroxyl)-N6(amino)[2.95],N2(amino)-N7[2.9...
# 4  O4'-N6(amino)[3.29],N2(amino)-N7[2.86],N3-N6(a...

# %%
ga_all_plus = ga_all[ga_all['dssr'].str.contains('\\+')]

# %%
ga_mpdot = ga_all_plus[ga_all_plus['dssr'].str.contains('m\\+\\.')]
ga_mpW = ga_all_plus[ga_all_plus['dssr'].str.contains('m\\+W')]
ga_mpm = ga_all_plus[ga_all_plus['dssr'].str.contains('m\\+m')]
ga_dotpM = ga_all_plus[ga_all_plus['dssr'].str.contains('\\.\\+M')]
ga_WpM = ga_all_plus[ga_all_plus['dssr'].str.contains('W\\+M')]
ga_MpW = ga_all_plus[ga_all_plus['dssr'].str.contains('M\\+W')]
ga_WpW = ga_all_plus[ga_all_plus['dssr'].str.contains('W\\+W')]
ga_mpM = ga_all_plus[ga_all_plus['dssr'].str.contains('m\\+M')]
ga_MpM = ga_all_plus[ga_all_plus['dssr'].str.contains('M\\+M')]
ga_dotpW = ga_all_plus[ga_all_plus['dssr'].str.contains('\\.\\+W')]

ga_dotpW.head()
# Out:
#      dssr  shear  stretch  opening  hb_num              hb_str
# 481   .+W   2.27    -4.78  -124.16       1  N2(amino)-N1[2.92]
# 699   .+W   2.45    -4.99  -127.48       1  N2(amino)-N1[3.09]
# 753   .+W   2.61    -5.34  -117.40       1  N2(amino)-N1[3.26]
# 778   .+W   1.63    -5.62  -142.67       1  N2(amino)-N1[3.32]
# 1042  .+W   2.43    -5.13  -120.15       1  N2(amino)-N1[2.87]

# %%
ga_dot_W = ga_all_minus[ga_all_minus['dssr'].str.contains('\\.-W')]

ga_W_W = ga_all_minus[ga_all_minus['dssr'].str.contains('W-W')]

ga_M_W = ga_all_minus[ga_all_minus['dssr'].str.contains('M-W')]

ga_W_M = ga_all_minus[ga_all_minus['dssr'].str.contains('W-M')]

ga_m_M = ga_all_minus[ga_all_minus['dssr'].str.contains('m-M')]

ga_m_m = ga_all_minus[ga_all_minus['dssr'].str.contains('m-m')]

ga_m_W = ga_all_minus[ga_all_minus['dssr'].str.contains('m-W')]

ga_W_m = ga_all_minus[ga_all_minus['dssr'].str.contains('W-m')]

ga_M_M = ga_all_minus[ga_all_minus['dssr'].str.contains('M-M')]

# %%
#df['desired_output'] = df['data'].apply(lambda x: 'true' if x <= 2.5 else 'false')
ga_MpM['opening'] = ga_MpM['opening'].apply(lambda x: x if x > 0 else -1*x)
ga_MpM['stretch'] = ga_MpM['stretch'].apply(lambda x: x if x < 0 else -1*x)
ga_MpM['shear'] = ga_MpM['shear'].apply(lambda x: x if x > 0 else -1*x)
# Out:
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
ga_WpW['opening'] = ga_WpW['opening'].apply(lambda x: x if x < 0 else -1*x)
ga_WpW['stretch'] = ga_WpW['stretch'].apply(lambda x: x if x < 0 else -1*x)
ga_WpW['shear'] = ga_WpW['shear'].apply(lambda x: x if x > 0 else -1*x)
# Out:
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
ga_mpm['opening'] = ga_mpm['opening'].apply(lambda x: x if x < 0 else -1*x)
ga_mpm['stretch'] = ga_mpm['stretch'].apply(lambda x: x if x < 0 else -1*x)
ga_mpm['shear'] = ga_mpm['shear'].apply(lambda x: x if x > 0 else -1*x)
# Out:
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
g = sns.jointplot(ga_all_plus['opening'],ga_all_plus['stretch'],ratio = 2,space = 0.2)
g.ax_joint.cla()
g.ax_marg_x.cla()
g.ax_marg_y.cla()

g.ax_joint.set_xlim(-190,190)
g.ax_joint.set_ylim(-10,10)
g.ax_marg_x.set_ylim(0,0.10)
g.ax_marg_y.set_xlim(0,2.0)

g.ax_joint.scatter(ga_dotpM['opening'],ga_dotpM['stretch'],c = '#d24425',data = ga_dotpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpW['opening'],ga_mpW['stretch'],c = 'g',data = ga_mpW, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpm['opening'],ga_mpm['stretch'],c = 'y',data = ga_mpm, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpdot['opening'],ga_mpdot['stretch'],c = 'b',data = ga_mpdot, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpM['opening'],ga_mpM['stretch'],c = 'k',data = ga_mpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_WpM['opening'],ga_WpM['stretch'],c = 'r',data = ga_WpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_MpW['opening'],ga_MpW['stretch'],c = '#fa9cec',data = ga_MpW, edgecolors= '#999796')

g.ax_joint.scatter(ga_WpW['opening'],ga_WpW['stretch'],c = 'c',data = ga_WpW, edgecolors= '#999796')

g.ax_joint.scatter(ga_MpM['opening'],ga_MpM['stretch'],c = 'm',data = ga_MpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_dotpW['opening'],ga_dotpW['stretch'],c = '#db902a',data = ga_dotpW, edgecolors= '#999796')


sns.kdeplot(data =  ga_dotpM['opening'], color = '#d24425', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpW['opening'], color = 'g',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpm['opening'], color = 'y',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =  ga_mpdot['opening'], color = 'b',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpM['opening'], color = 'k',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_WpM['opening'], color = 'r',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_MpW['opening'], color = '#fa9cec', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_WpW['opening'], color = 'c',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_MpM['opening'], color = 'm',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =  ga_dotpW['opening'], color = '#db902a', ax = g.ax_marg_x, legend = False)

sns.kdeplot(data =  ga_dotpM['stretch'], color = '#d24425', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpW['stretch'], color = 'g',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpm['stretch'], color = 'y',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =  ga_mpdot['stretch'], color = 'b',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpM['stretch'], color = 'k',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_WpM['stretch'], color = 'r',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_MpW['stretch'], color = '#fa9cec', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_WpW['stretch'], color = 'c',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_MpM['stretch'], color = 'm',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =  ga_dotpW['stretch'], color = '#db902a', ax = g.ax_marg_y, legend = False,vertical = True)
#g.ax_joint.scatter(ga_all_plus['opening'],ga_all_plus['stretch'],c = 'r',data = ga_all_plus)
labels = ['.+M','m+W','m+m','m+.','m+M','W+M','M+W','W+W','M+M','.+W']
g.ax_joint.legend(labels,loc='center right', bbox_to_anchor=(2, 0.5))

# %%
g = sns.jointplot(ga_all_plus['opening'],ga_all_plus['stretch'],ratio = 2,space = 0.2)
g.ax_joint.cla()
g.ax_marg_x.cla()
g.ax_marg_y.cla()

g.ax_joint.set_xlim(-190,190)
g.ax_joint.set_ylim(-10,10)
g.ax_marg_x.set_ylim(0,0.10)
g.ax_marg_y.set_xlim(0,2.0)

g.ax_joint.scatter(ga_dotpM['opening'],ga_dotpM['shear'],c = '#d24425',data = ga_dotpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpW['opening'],ga_mpW['shear'],c = 'g',data = ga_mpW, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpm['opening'],ga_mpm['shear'],c = 'y',data = ga_mpm, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpdot['opening'],ga_mpdot['shear'],c = 'b',data = ga_mpdot, edgecolors= '#999796')

g.ax_joint.scatter(ga_mpM['opening'],ga_mpM['shear'],c = 'k',data = ga_mpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_WpM['opening'],ga_WpM['shear'],c = 'r',data = ga_WpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_MpW['opening'],ga_MpW['shear'],c = '#fa9cec',data = ga_MpW, edgecolors= '#999796')

g.ax_joint.scatter(ga_WpW['opening'],ga_WpW['shear'],c = 'c',data = ga_WpW, edgecolors= '#999796')

g.ax_joint.scatter(ga_MpM['opening'],ga_MpM['shear'],c = 'm',data = ga_MpM, edgecolors= '#999796')

g.ax_joint.scatter(ga_dotpW['opening'],ga_dotpW['shear'],c = '#db902a',data = ga_dotpW, edgecolors= '#999796')


sns.kdeplot(data =  ga_dotpM['opening'], color = '#d24425', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpW['opening'], color = 'g',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpm['opening'], color = 'y',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =  ga_mpdot['opening'], color = 'b',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpM['opening'], color = 'k',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_WpM['opening'], color = 'r',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_MpW['opening'], color = '#fa9cec', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_WpW['opening'], color = 'c',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_MpM['opening'], color = 'm',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =  ga_dotpW['opening'], color = '#db902a', ax = g.ax_marg_x, legend = False)

sns.kdeplot(data =  ga_dotpM['shear'], color = '#d24425', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpW['shear'], color = 'g',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpm['shear'], color = 'y',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =  ga_mpdot['shear'], color = 'b',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpM['shear'], color = 'k',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_WpM['shear'], color = 'r',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_MpW['shear'], color = '#fa9cec', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_WpW['shear'], color = 'c',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_MpM['shear'], color = 'm',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =  ga_dotpW['shear'], color = '#db902a', ax = g.ax_marg_y, legend = False,vertical = True)
#g.ax_joint.scatter(ga_all_plus['opening'],ga_all_plus['stretch'],c = 'r',data = ga_all_plus)
labels = ['.+M','m+W','m+m','m+.','m+M','W+M','M+W','W+W','M+M','.+W']
g.ax_joint.legend(labels,loc='center right', bbox_to_anchor=(2, 0.5))

# %%
g = sns.jointplot(ga_all_plus['opening'],ga_all_plus['stretch'],ratio = 2,space = 0.2)
g.ax_joint.cla()
g.ax_marg_x.cla()
g.ax_marg_y.cla()

g.ax_joint.set_xlim(-12,12)
g.ax_joint.set_ylim(-12,12)
g.ax_marg_x.set_ylim(0,2.5)
g.ax_marg_y.set_xlim(0,2.5)

g.ax_joint.scatter( ga_dotpM['stretch'],ga_dotpM['shear'],c = '#d24425',data = ga_dotpM, edgecolors= '#999796')

g.ax_joint.scatter(   ga_mpW['stretch'],  ga_mpW['shear'],c = 'g',data = ga_mpW, edgecolors= '#999796')

g.ax_joint.scatter(   ga_mpm['stretch'],  ga_mpm['shear'],c = 'y',data = ga_mpm, edgecolors= '#999796')

g.ax_joint.scatter( ga_mpdot['stretch'],ga_mpdot['shear'],c = 'b',data = ga_mpdot, edgecolors= '#999796')

g.ax_joint.scatter(   ga_mpM['stretch'],  ga_mpM['shear'],c = 'k',data = ga_mpM, edgecolors= '#999796')

g.ax_joint.scatter(   ga_WpM['stretch'],  ga_WpM['shear'],c = 'r',data = ga_WpM, edgecolors= '#999796')

g.ax_joint.scatter(   ga_MpW['stretch'],  ga_MpW['shear'],c = '#fa9cec',data = ga_MpW, edgecolors= '#999796')

g.ax_joint.scatter(   ga_WpW['stretch'],  ga_WpW['shear'],c = 'c',data = ga_WpW, edgecolors= '#999796')

g.ax_joint.scatter(   ga_MpM['stretch'],  ga_MpM['shear'],c = 'm',data = ga_MpM, edgecolors= '#999796')

g.ax_joint.scatter( ga_dotpW['stretch'],ga_dotpW['shear'],c = '#db902a',data = ga_dotpW, edgecolors= '#999796')


sns.kdeplot(data =  ga_dotpM['stretch'], color = '#d24425', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpW['stretch'], color = 'g',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpm['stretch'], color = 'y',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =  ga_mpdot['stretch'], color = 'b',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_mpM['stretch'], color = 'k',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_WpM['stretch'], color = 'r',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_MpW['stretch'], color = '#fa9cec', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_WpW['stretch'], color = 'c',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_MpM['stretch'], color = 'm',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =  ga_dotpW['stretch'], color = '#db902a', ax = g.ax_marg_x, legend = False)

sns.kdeplot(data =  ga_dotpM['shear'], color = '#d24425', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpW['shear'], color = 'g',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpm['shear'], color = 'y',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =  ga_mpdot['shear'], color = 'b',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_mpM['shear'], color = 'k',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_WpM['shear'], color = 'r',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_MpW['shear'], color = '#fa9cec', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_WpW['shear'], color = 'c',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_MpM['shear'], color = 'm',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =  ga_dotpW['shear'], color = '#db902a', ax = g.ax_marg_y, legend = False,vertical = True)
#g.ax_joint.scatter(ga_all_plus['opening'],ga_all_plus['stretch'],c = 'r',data = ga_all_plus)
labels = ['.+M','m+W','m+m','m+.','m+M','W+M','M+W','W+W','M+M','.+W']
g.ax_joint.legend(labels,loc='center right', bbox_to_anchor=(2, 0.5))

# %%
ga_M_M['opening'] = ga_M_M['opening'].apply(lambda x: x if x < 0 else -1*x)
ga_M_M['stretch'] = ga_M_M['stretch'].apply(lambda x: x if x > 0 else -1*x)
#ga_M_M['shear'] = ga_WpW['shear'].apply(lambda x: x if x > 0 else -1*x)
ga_m_m['opening'] = ga_m_m['opening'].apply(lambda x: x if x > 0 else -1*x)
ga_m_m['stretch'] = ga_m_m['stretch'].apply(lambda x: x if x > 0 else -1*x)
# Out:
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Student\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
g = sns.jointplot(ga_all_plus['opening'],ga_all_plus['stretch'],ratio = 2,space = 0.2)
g.ax_joint.cla()
g.ax_marg_x.cla()
g.ax_marg_y.cla()

g.ax_joint.set_xlim(-190,190)
g.ax_joint.set_ylim(-10,10)
g.ax_marg_x.set_ylim(0,0.10)
g.ax_marg_y.set_xlim(0,2.0)

g.ax_joint.scatter(ga_dot_W['opening'],ga_dot_W['stretch'],c = '#d24425',data = ga_dot_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_W['opening'],ga_W_W['stretch'],c = 'g',data = ga_W_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_M_W['opening'],ga_M_W['stretch'],c = 'y',data = ga_M_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_M['opening'],ga_W_M['stretch'],c = 'b',data = ga_W_M, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_M['opening'],ga_m_M['stretch'],c = 'k',data = ga_m_M, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_m['opening'],ga_m_m['stretch'],c = 'r',data = ga_m_m, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_W['opening'],ga_m_W['stretch'],c = '#fa9cec',data = ga_m_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_m['opening'],ga_W_m['stretch'],c = 'c',data = ga_W_m, edgecolors= '#999796')

g.ax_joint.scatter(  ga_M_M['opening'],ga_M_M['stretch'],c = 'm',data = ga_M_M, edgecolors= '#999796')


sns.kdeplot(data =  ga_dot_W['opening'], color = '#d24425', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_W['opening'], color = 'g',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_M_W['opening'], color = 'y',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_M['opening'], color = 'b',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_M['opening'], color = 'k',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_m['opening'], color = 'r',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_W['opening'], color = '#fa9cec', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_m['opening'], color = 'c',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_M_M['opening'], color = 'm',       ax = g.ax_marg_x, legend = False)


sns.kdeplot(data =  ga_dot_W['stretch'], color = '#d24425', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_W['stretch'], color = 'g',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_M_W['stretch'], color = 'y',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_M['stretch'], color = 'b',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_M['stretch'], color = 'k',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_m['stretch'], color = 'r',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_W['stretch'], color = '#fa9cec', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_m['stretch'], color = 'c',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_M_M['stretch'], color = 'm',       ax = g.ax_marg_y, legend = False,vertical = True)

#g.ax_joint.scatter(ga_all_plus['opening'],ga_all_plus['stretch'],c = 'r',data = ga_all_plus)
labels = ['.-W','W-W','M-W','W-M','m-M','m-m','m-W','W-m','M-M']
g.ax_joint.legend(labels,loc='center right', bbox_to_anchor=(2, 0.5))

# %%
g = sns.jointplot(ga_all_plus['opening'],ga_all_plus['stretch'],ratio = 2,space = 0.2)
g.ax_joint.cla()
g.ax_marg_x.cla()
g.ax_marg_y.cla()

g.ax_joint.set_xlim(-190,190)
g.ax_joint.set_ylim(-10,10)
g.ax_marg_x.set_ylim(0,0.10)
g.ax_marg_y.set_xlim(0,2.0)

g.ax_joint.scatter(ga_dot_W['opening'],ga_dot_W['shear'],c = '#d24425',data = ga_dot_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_W['opening'],  ga_W_W['shear'],c = 'g',data = ga_W_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_M_W['opening'],  ga_M_W['shear'],c = 'y',data = ga_M_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_M['opening'],  ga_W_M['shear'],c = 'b',data = ga_W_M, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_M['opening'],  ga_m_M['shear'],c = 'k',data = ga_m_M, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_m['opening'],  ga_m_m['shear'],c = 'r',data = ga_m_m, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_W['opening'],  ga_m_W['shear'],c = '#fa9cec',data = ga_m_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_m['opening'],  ga_W_m['shear'],c = 'c',data = ga_W_m, edgecolors= '#999796')

g.ax_joint.scatter(  ga_M_M['opening'],  ga_M_M['shear'],c = 'm',data = ga_M_M, edgecolors= '#999796')


sns.kdeplot(data =  ga_dot_W['opening'], color = '#d24425', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_W['opening'], color = 'g',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_M_W['opening'], color = 'y',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_M['opening'], color = 'b',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_M['opening'], color = 'k',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_m['opening'], color = 'r',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_W['opening'], color = '#fa9cec', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_m['opening'], color = 'c',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_M_M['opening'], color = 'm',       ax = g.ax_marg_x, legend = False)


sns.kdeplot(data =  ga_dot_W['shear'], color = '#d24425', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_W['shear'], color = 'g',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_M_W['shear'], color = 'y',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_M['shear'], color = 'b',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_M['shear'], color = 'k',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_m['shear'], color = 'r',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_W['shear'], color = '#fa9cec', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_m['shear'], color = 'c',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_M_M['shear'], color = 'm',       ax = g.ax_marg_y, legend = False,vertical = True)

#g.ax_joint.scatter(ga_all_plus['opening'],ga_all_plus['stretch'],c = 'r',data = ga_all_plus)
labels = ['.-W','W-W','M-W','W-M','m-M','m-m','m-W','W-m','M-M']
g.ax_joint.legend(labels,loc='center right', bbox_to_anchor=(2, 0.5))

# %%
g = sns.jointplot(ga_all_plus['opening'],ga_all_plus['stretch'],ratio = 2,space = 0.2)
g.ax_joint.cla()
g.ax_marg_x.cla()
g.ax_marg_y.cla()

g.ax_joint.set_xlim(-12,12)
g.ax_joint.set_ylim(-12,12)
g.ax_marg_x.set_ylim(0,2.5)
g.ax_marg_y.set_xlim(0,2.5)

g.ax_joint.scatter(ga_dot_W['stretch'],ga_dot_W['shear'],c = '#d24425',data = ga_dot_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_W['stretch'],  ga_W_W['shear'],c = 'g',data = ga_W_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_M_W['stretch'],  ga_M_W['shear'],c = 'y',data = ga_M_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_M['stretch'],  ga_W_M['shear'],c = 'b',data = ga_W_M, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_M['stretch'],  ga_m_M['shear'],c = 'k',data = ga_m_M, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_m['stretch'],  ga_m_m['shear'],c = 'r',data = ga_m_m, edgecolors= '#999796')

g.ax_joint.scatter(  ga_m_W['stretch'],  ga_m_W['shear'],c = '#fa9cec',data = ga_m_W, edgecolors= '#999796')

g.ax_joint.scatter(  ga_W_m['stretch'],  ga_W_m['shear'],c = 'c',data = ga_W_m, edgecolors= '#999796')

g.ax_joint.scatter(  ga_M_M['stretch'],  ga_M_M['shear'],c = 'm',data = ga_M_M, edgecolors= '#999796')


sns.kdeplot(data =  ga_dot_W['stretch'], color = '#d24425', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_W['stretch'], color = 'g',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_M_W['stretch'], color = 'y',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_M['stretch'], color = 'b',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_M['stretch'], color = 'k',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_m['stretch'], color = 'r',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_m_W['stretch'], color = '#fa9cec', ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_W_m['stretch'], color = 'c',       ax = g.ax_marg_x, legend = False)
sns.kdeplot(data =    ga_M_M['stretch'], color = 'm',       ax = g.ax_marg_x, legend = False)


sns.kdeplot(data =  ga_dot_W['shear'], color = '#d24425', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_W['shear'], color = 'g',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_M_W['shear'], color = 'y',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_M['shear'], color = 'b',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_M['shear'], color = 'k',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_m['shear'], color = 'r',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_m_W['shear'], color = '#fa9cec', ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_W_m['shear'], color = 'c',       ax = g.ax_marg_y, legend = False,vertical = True)
sns.kdeplot(data =    ga_M_M['shear'], color = 'm',       ax = g.ax_marg_y, legend = False,vertical = True)

#g.ax_joint.scatter(ga_all_plus['opening'],ga_all_plus['stretch'],c = 'r',data = ga_all_plus)
labels = ['.-W','W-W','M-W','W-M','m-M','m-m','m-W','W-m','M-M']
g.ax_joint.legend(labels,loc='center right', bbox_to_anchor=(2, 0.5))
